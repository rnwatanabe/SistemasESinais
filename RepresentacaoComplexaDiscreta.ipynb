# %% [markdown]
# # Sinais exponenciais de tempo discreto
#
# Renato Naville Watanabe

# %% [markdown]
# ## Exponencial real

# %% [markdown]
# Em sinais discretos a exponencial real é definida da seguinte maneira:
#
# $$x[n] = Ae^{\beta n}$$
#
# Embora a expressão acima esteja correta, para sinais de tempo discreto é comum definirmos $\alpha = e^\beta$. Com isso, temos:
#
# $$x[n] = A\alpha^n$$
#
# Com $\alpha$ e $A$ reais.

# %% [markdown]
# Note que se $\alpha > 1$, a sequência $x[n]$ sempre aumenta, como é possível ver no gráfico abaixo (com $A=1$ e $\alpha=1.5$):

# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(20)
A = 1
alpha = 1.5
x = A*alpha**n
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# No caso de $0 < \alpha < 1$, a sequência $x[n]$ sempre diminui, como é possível ver no gráfico abaixo (com $A=1$ e $\alpha=0.5$):

# %%
n = np.arange(20)
A = 1
alpha = 0.5
x = A*alpha**n
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# Para valores de $\alpha$ negativos, o sinal se torna oscilatório (quando $n$ é par, $x[n]$ é positivo, e quando $n$ é ímpar, $x[n]$ é negativo). Isso é possível de se observar no gráfico abaixo (com $A=1$ e $\alpha=-0.8$):

# %%
n = np.arange(20)
A = 1
alpha = -0.8
x = A*alpha**n
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# O sinal acima oscila e decai. Isso acontece porque $-1<\alpha<0$. Caso $\alpha < -1$, a amplitude do sinal aumentará, como visto abaixo (com $A = 1$ e $\alpha = -1.2$)

# %%
n = np.arange(20)
A = 1
alpha = -1.2
x = A*alpha**n
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ## Exponencial complexa

# %% [markdown]
# Da mesma forma que no caso contínuo, podemos definir um sinal com o expoente complexo:
#
# $$x[n] = e^{j\omega_0 n}$$
#
# Pela relação de Euler-Moivre, este sinal está totalmente relacionado com o cosseno:
#
# $$x[n] = A\cos(\omega_0 n + \theta) = A\frac{e^{j(\omega_0 n + \theta)} + e^{-j(\omega_0 n + \theta)}}{2}$$
#
# Abaixo, o gráfico do cosseno com $\omega_0 = \pi/12$

# %%
n = np.arange(40)
A = 1
omega0= np.pi/12
x = A*np.cos(omega0*n)
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# com $\omega_0 = \pi/6$

# %%
n = np.arange(40)
A = 1
omega0= np.pi/6
x = A*np.cos(omega0*n)
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# com $\omega_0 = \pi/3$

# %%
n = np.arange(40)
A = 1
omega0= np.pi/3
x = A*np.cos(omega0*n)
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# com $\omega_0 = \frac{2\pi}{3}$.

# %%
n = np.arange(40)
A = 1
omega0= 2*np.pi/3
x = A*np.cos(omega0*n)
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# com $\omega_0 = \pi$.

# %%
n = np.arange(40)
A = 1
omega0= np.pi
x = A*np.cos(omega0*n)
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# com $\omega_0 = \frac{4\pi}{3}$.

# %%
n = np.arange(40)
A = 1
omega0= 4*np.pi/3
x = A*np.cos(omega0*n)
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# com $\omega_0 = \frac{5\pi}{3}$.

# %%
n = np.arange(40)
A = 1
omega0= 5*np.pi/3
x = A*np.cos(omega0*n)
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# com $\omega_0 = \frac{11\pi}{6}$.

# %%
n = np.arange(40)
A = 1
omega0= 11*np.pi/6
x = A*np.cos(omega0*n)
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# com $\omega_0 = \frac{23\pi}{12}$.

# %%
n = np.arange(40)
A = 1
omega0= 23*np.pi/12
x = A*np.cos(omega0*n)
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ### Caso geral

# %% [markdown]
# ## Exercícios

# %% [markdown]
# **1)** Determine se os sinais abaixo são periódicos ou não. Se for periódico, determine qual o período fundamental do sinal.
#
#
#
# a) $x_1[n] = e^{j5\pi n}$
#
# b) $x_2[n] = 3e^{j\frac{3}{4}\left(n+\frac{3}{4}\right)}$

# %% [markdown]
# ## Referências
#
# - Oppenheim, M. Sistemas e Sinais, 2010
# - Ulaby, FT e Yagle, AE, Signals & Systems: Theory and Applications, 2018, [ss2.eecs.umich.edu](ss2.eecs.umich.edu)
# - Lathi, BP, Sinais e Sistemas Lineares, 2007
