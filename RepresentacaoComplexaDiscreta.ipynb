# %% [markdown]
# # Sinais exponenciais de tempo discreto
#
# Renato Naville Watanabe

# %% [markdown]
# ## Preparação do ambiente

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exponencial real

# %% [markdown]
# Em sinais discretos a exponencial real é definida da seguinte maneira:
#
# $$x[n] = Ae^{\lambda n}$$
#
# Embora a expressão acima esteja correta, para sinais de tempo discreto é comum definirmos $\alpha = e^\lambda$. Com isso, temos:
#
# $$x[n] = A\alpha^n$$
#
# Com $\alpha$ e $A$ reais.

# %% [markdown]
# Note que se $\alpha > 1$, a sequência $x[n]$ sempre aumenta, como é possível ver no gráfico abaixo (com $A=1$ e $\alpha=1.5$):

# %%
n = np.arange(20)
A = 1
alpha = 1.5
x = A*alpha**n
plt.stem(n, x);

# %% [markdown]
# No caso de $0 < \alpha < 1$, a sequência $x[n]$ sempre diminui, como é possível ver no gráfico abaixo (com $A=1$ e $\alpha=0.5$):

# %%
n = np.arange(20)
A = 1
alpha = 0.5
x = A*alpha**n
plt.stem(n, x);

# %% [markdown]
# Para valores de $\alpha$ negativos, o sinal se torna oscilatório (quando $n$ é par, $x[n]$ é positivo, e quando $n$ é ímpar, $x[n]$ é negativo). Isso é possível de se observar no gráfico abaixo (com $A=1$ e $\alpha=-0.8$):

# %%
n = np.arange(20)
A = 1
alpha = -0.8
x = A*alpha**n
plt.stem(n, x);

# %% [markdown]
# O sinal acima oscila e decai. Isso acontece porque $-1<\alpha<0$. Caso $\alpha < -1$, a amplitude do sinal aumentará, como visto abaixo (com $A = 1$ e $\alpha = -1.2$)

# %%
n = np.arange(20)
A = 1
alpha = -1.2
x = A*alpha**n
plt.stem(n, x);

# %% [markdown]
# ## Exponencial complexa

# %% [markdown]
# Da mesma forma que no caso contínuo, podemos definir um sinal com o expoente complexo:
#
# $$x[n] = e^{j\omega_0 n}$$
#
# Pela relação de Euler-Moivre, este sinal está totalmente relacionado com o cosseno:
#
# $$x[n] = A\cos(\omega_0 n + \theta) = A\frac{e^{j(\omega_0 n + \theta)} + e^{-j(\omega_0 n + \theta)}}{2}$$
#
# Abaixo, são mostrados diversos sinais cosseno, com diferentes frequências (as frequências sobem ao longo dos gráficos, da esquerda para a direita e de cima para baixo).

# %%
fig, ax = plt.subplots(3, 4, figsize=(10, 8), sharey=True, sharex=True)


n = np.arange(40)
A = 1
omega0= np.pi/12
x = A*np.cos(omega0*n)
ax[0,0].stem(n, x)
ax[0,0].title.set_text(r'$\omega_0=\pi/12$')

n = np.arange(40)
A = 1
omega0= np.pi/6
x = A*np.cos(omega0*n)
ax[0,1].stem(n, x)
ax[0,1].title.set_text(r'$\omega_0=\pi/6$')

n = np.arange(40)
A = 1
omega0= np.pi/3
x = A*np.cos(omega0*n)
ax[0,2].stem(n, x)
ax[0,2].title.set_text(r'$\omega_0=\pi/3$')

n = np.arange(40)
A = 1
omega0= 2*np.pi/3
x = A*np.cos(omega0*n)
ax[0,3].stem(n, x)
ax[0,3].title.set_text(r'$\omega_0=2\pi/3$')

n = np.arange(40)
A = 1
omega0= np.pi
x = A*np.cos(omega0*n)
ax[1,0].stem(n, x)
ax[1,0].title.set_text(r'$\omega_0=\pi$')

n = np.arange(40)
A = 1
omega0= 4*np.pi/3
x = A*np.cos(omega0*n)
ax[1,1].stem(n, x)
ax[1,1].title.set_text(r'$\omega_0=4\pi/3$')

n = np.arange(40)
A = 1
omega0= 5*np.pi/3
x = A*np.cos(omega0*n)
ax[1,2].stem(n, x)
ax[1,2].title.set_text(r'$\omega_0=5\pi/3$')

n = np.arange(40)
A = 1
omega0= 11*np.pi/6
x = A*np.cos(omega0*n)
ax[1,3].stem(n, x)
ax[1,3].title.set_text(r'$\omega_0=11\pi/6$')

n = np.arange(40)
A = 1
omega0= 23*np.pi/12
x = A*np.cos(omega0*n)
ax[2,0].stem(n, x)
ax[2,0].title.set_text(r'$\omega_0=23\pi/12$')

n = np.arange(40)
A = 1
omega0= 2*np.pi
x = A*np.cos(omega0*n)
ax[2,1].stem(n, x)
ax[2,1].title.set_text(r'$\omega_0=2\pi$')

n = np.arange(40)
A = 1
omega0= 25*np.pi/12
x = A*np.cos(omega0*n)
ax[2,2].stem(n, x)
ax[2,2].title.set_text(r'$\omega_0=25\pi/12$')

n = np.arange(40)
A = 1
omega0= 13*np.pi/6
x = A*np.cos(omega0*n)
ax[2,3].stem(n, x)
ax[2,3].title.set_text(r'$\omega_0=13\pi/6$')

# %% [markdown]
# Note que até $\omega_0=\pi$ a oscilação ficou mais rápida com o crescimento de $\omega_0$. Porém, diferentemente do sinal de tempo contínuo, que aumenta a oscilação fica sempre mais rápida com o aumento da frequência, no sinal de tempo discreto isso não acontece. Existem duas coisas a serem observadas aqui:
#
# - quando aumentamos a frequência em $2\pi$, o sinal não muda. Isso acontece porque $e^{j(\omega_0+2\pi)n} = e^{j\omega_0 n}e^{j2\pi n}=e^{j\omega_0}1=e^{j\omega_0 n}$. Por isso quando $\omega_0 = \frac{25\pi}{12}$ o sinal é igual a quando $\omega_0 = \frac{\pi}{12}$ ($\frac{\pi}{12} + 2\pi= \frac{25\pi}{12}$). Da mesma forma, quando $\omega_0 = \frac{13\pi}{6}$ o sinal é igual a quando $\omega_0 = \frac{\pi}{6}$ ($\frac{\pi}{6} + 2\pi= \frac{13\pi}{6}$).
#
# - quando $\pi \leq \omega_0 < 2\pi$ (ou esses valores adicionados de múltiplos de $2\pi$), podemos interpretar $\omega_0$ como sendo o negativo do seu complemento para $2\pi$ (por exemplo, para $\omega_0=\frac{5\pi}{3}$, $e^{j\frac{5\pi}{3}n} = e^{-j\frac{\pi}{3}n}$). Então, pela fórmula de Euler-Moivre:
#
# $$\cos\left(\frac{5\pi}{3}n\right) = \frac{e^{j\frac{5\pi}{3}n}+e^{-j\frac{5\pi}{3}n}}{2} = \frac{e^{-j\frac{\pi}{3}n}+e^{j\frac{\pi}{3}n}}{2}=\cos\left(\frac{\pi}{3}n\right) $$
#
# Por isso, o sinal com $\omega_0=\frac{11\pi}{6}$ é igual ao sinal de quando $\omega_0=\frac{\pi}{6}$, o sinal com $\omega_0=\frac{4\pi}{3}$ é igual ao sinal de quando $\omega_0=\frac{2\pi}{3}$ e o sinal com $\omega_0=\frac{23\pi}{12}$ é igual ao sinal de quando $\omega_0=\frac{\pi}{12}$.

# %% [markdown]
# Uma outra diferença em relação ao cosseno (e exponencial complexa) de tempo contínuo é que nem sempre o sinal vai ser periódico. Para percebermos isso, vamos usar a definição de sinal periódico:
#
# $$e^{j\omega_0 n} = e^{j\omega_0 (n+N)} = e^{j\omega_0 n}e^{j\omega_0 N}$$
#
# A expressão acima só vai ter os dois lados iguais se:
#
# $$ e^{j\omega_0 N} = 1$$
#
# Isso só vai acontecer se existir algum $N$ inteiro que faça $\omega_0 N=2\pi$. Se existir, esse $N$ é que é o período fundamental do sinal. Mas, para existir, $\frac{\omega_0}{2\pi}$ precisa ser racional. Se essa divisão não for racional, o sinal não será periódico. Por exemplo, para:
#
# $$x[n] = \cos(0.6n)$$

# %%
n = np.arange(40)
A = 1
omega0 = 0.6
x = np.cos(omega0*n)
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# Note que os valores nunca se repetem (e nunca irão se repetir), e portanto o sinal é não periódico. Podemos notar que $\frac{0.6}{2\pi}$ é não racional (não é posível escrever como fração).

# %% [markdown]
# ### Caso geral

# %% [markdown]
# Um sinal exponencial complexo mais geral é da forma:
#
# $$x[n] = \frac{Ae^{rn + j\omega n + j\theta} + Ae^{rn - j\omega n - j\theta}}{2} = Ae^{rn}\frac{e^{j(\omega n + \theta)}+e^{-j(\omega n + \theta)}}{2} = Ae^{rn}\cos(\omega n+\theta) = A\alpha^n\cos(\omega n+\theta)$$
#
# O gráfico desse sinal, caso $alpha>1$, é a cossenoide com a sua amplitude modulada pela exponencial crescente:

# %%
n = np.arange(40)
A = 1
alpha = 1.1
omega0= 11*np.pi/6
x = A*alpha**n*np.cos(omega0*n)
plt.stem(n, x);

# %% [markdown]
# E no caso de $0<\alpha<1$, é a cossenoide com a sua amplitude modulada pela exponencial decrescente:

# %%
n = np.arange(40)
A = 1
alpha = 0.8
omega0= 11*np.pi/6
x = A*alpha**n*np.cos(omega0*n)
plt.stem(n, x);

# %% [markdown]
# ### Somatório de exponencias complexas harmonicamente relacionadas
#
# Exponenciais harmonicamente relacionadas $\phi_k[n]$ são exponenciais complexas que têm um período $N$ em comum (o termo "harmônico" tem o mesmo significado do empregado em música). Ou seja, são sinais com frequências que são múltiplas da menor frequência encontrada entre os sinais.
#
# $\phi_k[n] = A_ke^{jk\omega_0 n}, k = 0,\pm 1,\pm 2 ...$
#
# Para $k = 0$ o sinal é uma constante e para os outros valores de $k$ a frequência angular do sinal  é $|k|\omega_0$. O período fundamental de um sinal que seja a soma dessas exponenciais harmônicas é:
#
# $N_0 = \frac{2\pi k}{\omega_0}$
#
# com $N_0$ inteiro e $k$ inteiro. Se não existir $N_0$ inteiro para nenhum $k$ inteiro, o sinal não é periódico.
#
# Devido à fórmula de Euler-Moivre, isso também vale para conjunto de senos e cossenos que sejam harmonicamente relacionados.

# %% [markdown]
# Por exemplo, o sinal:
#
# $x[n] = \cos\left(\frac{\pi}{6}n\right) + 0.5\cos\left(2\frac{\pi}{6}n\right)$
#
# a frequência $\omega_0=\frac{\pi}{6}$ rad. Então o período fundamental do sinal é $N_0=\frac{2\pi}{\pi/6} = 12$, como é possível observar pelo gráfico abaixo ( o gráfico se repete a cada 12 instantes discretos):

# %%
n = np.arange(40)
x = np.cos(np.pi/6*n)+0.5*np.cos(np.pi/3*n)
plt.stem(n, x);

# %% [markdown]
# Nem sempre é tão óbvio qual a frequência angular fundamental $\omega_0$. Por exemplo, o sinal abaixo:
#
# $x[n] = \cos\left(0,07\pi n\right) + 0.5\cos\left(0,06\pi n\right)$
#
# Num primeiro momento você pode achar que $\omega_0=0,06\pi$. Mas $0,07\pi$ não é múltiplo de $0,06\pi$, então esta não é a frequência angular fundamental. Nesse caso $\omega_0= 0,01\pi$ e o período fundamental é $N_0=\frac{2\pi k}{0,01\pi}=\frac{200k}{1} = 200$ (com $k = 1$).

# %%
n = np.arange(300)
x = np.cos(0.07*np.pi*n)+np.cos(0.06*np.pi*n)
plt.stem(n, x);

# %% [markdown]
# Então, de uma forma geral, para encontrarmos a frequência fundamental $\omega_0$ em um sinal gerado por uma soma de senoides é o máximo divisor comum entre as frequências de cada senoide que compõe o sinal.

# %% [markdown]
# ## Exercícios

# %% [markdown]
# **1)** Determine se os sinais abaixo são periódicos ou não. Se for periódico, determine qual o período fundamental do sinal.
#
# a) $x_1[n] = e^{j5\pi n}$
#
# b) $x_2[n] = 3e^{j\frac{3}{4}\left(n+\frac{3}{4}\right)}$
#
# c) $x_3[n] = \mathrm{sen}\left(\frac{6\pi}{7}n+1 \right)$
#
# d) $x_4[n] = \mathrm{cos}\left(\frac{n}{8}n-\pi \right)$
#
# e) $x_5[n] = \mathrm{cos}\left(\frac{\pi}{8}n^2\right)$
#
# f) $x_6[n] = \mathrm{cos}\left(\frac{\pi}{2}n\right)\mathrm{cos}\left(\frac{\pi}{4}n\right)$
#
# g) $x_7[n] = 3\cos\left(0.16\pi n + 1\right)+ 4\cos\left(0.15\pi n+2\right)$

# %% [markdown]
# **2)** Qual o período fundamental do sinal abaixo?

# %%
omega0 = np.pi/13
x = 3*np.cos(omega0*n)+ 2*np.sin(3*omega0*n+0.5)
plt.stem(n, x);

# %% [markdown]
# **3)** Encontre uma expressão para os sinal $x[n]$ mostrado no gráfico abaixo:

# %%
n = np.arange(20)
A = 4
alpha = -0.75
x = A*alpha**n
plt.stem(n, x)
plt.xlabel('n');

# %% [markdown]
# **4)** Coloque os sinais abaixo, que estão na forma $e^{\lambda n}$ na forma $\alpha^n$. Identifique quais dos sinais tem o módulo crescente, decrescente e constante. Desenhe no plano complexo os valores de $\lambda$ e os valores de $\alpha$:
#
# a) $x_1[n] = e^{-0.2n}$
#
# b) $x_2[n] = e^{0.2n}$
#
# c) $x_3[n] = e^{j\frac{\pi}{2} n}$
#
# d) $x_4[n] = e^{-j\frac{\pi}{2} n}$

# %% [markdown]
# **5)**  Coloque os sinais abaixo, que estão na forma $e^{\lambda n}$ na forma $\alpha^n$. Identifique quais dos sinais tem o módulo crescente, decrescente e constante. Desenhe no plano complexo os valores de $\lambda$ e os valores de $\alpha$:
#
# a) $x_1[n] = e^{(-0.2+j\frac{\pi}{3})n}$
#
# b) $x_2[n] = e^{(-0.2-j\frac{\pi}{3})n}$
#
# c) $x_3[n] = e^{(0.2+j\frac{\pi}{3})n}$
#
# d) $x_4[n] = e^{(0.2-j\frac{\pi}{3})n}$
#
# e) $x_5[n] = e^{(0.2-j\pi)n}$
#
# f) $x_6[n] = e^{(-0.2+j\pi)n}$

# %% [markdown]
# **6)** Calcule o período fundamental dos seguintes sinais:
#
# a) $x_1[n] = \cos\left(\frac{2\pi}{10}n\right)$
#
# b) $x_2[n] = \cos\left(\frac{\pi}{10}n\right)$
#
# c) $x_3[n] = \cos\left(\frac{2\pi}{4}n\right) + \cos\left(\frac{2\pi}{7}n\right) $
#
# d) $x_4[n] = \frac{e^{j\frac{\pi}{4}n}+ e^{-j\frac{\pi}{4}n}}{2}$
#
# e) $x_5[n] = \frac{e^{j\frac{\pi}{20}n}+ e^{-j\frac{\pi}{20}n}}{2}$

# %% [markdown]
# ## Referências
#
# - Oppenheim, M.  e Willsky, S., Sistemas e Sinais, 2010
# - Ulaby, FT e Yagle, AE, Signals & Systems: Theory and Applications, 2018, [ss2.eecs.umich.edu](ss2.eecs.umich.edu)
# - Lathi, BP, Sinais e Sistemas Lineares, 2007
# - Roberts, Michael J. Fundamentos de sinais e sistemas, 2009.

# %% [markdown]
# ## Solução dos exercícios

# %% [markdown]
# **1)** Resolvido por Catherine
#
# a) **Periódico**
#
# Para determinar o período fundamental do sinal, devemos encontrar o menor valor de $T$ tal que:
#
# $$
# x_1[t] = x_1[t + T]
# $$
#
# Para $t = 0$, temos:
#
# $$
# x_1[0] = e^{j5\pi \cdot 0} = 1
# $$
#
# Para $t = T$, temos:
#
# $$
# x_1[T] = e^{j5\pi \cdot T} = e^{j5\pi T}
# $$
#
# Para que $x_1[t] = x_1[t + T]$, devemos ter $e^{j5\pi T} = 1$.
#
# $$
# e^{j5\pi T} = e^{2\pi j}
# $$
#
# Aplicando a identidade de Euler, temos:
#
# $$
# e^{j5\pi N} = e^{2\pi j} = e^{2\pi j (\frac{2}{5})} = e^{j4\pi}
# $$
#
# $e^{j5\pi N} = 1$ ocorre para $T = \frac{2\pi}{5\pi} = \frac{2}{5}$
#
# b) **Periódico**
#
# $$x_2[t] = 3e^{j\frac{3}{4}\left(n+\frac{3}{4}\right)}$$
#
# $$x_2[t] = x_2[t + T]$$
#
# $$3e^{j\frac{3}{4}t} = 3e^{j\frac{3}{4}(t + T)}$$
#
# $$e^{j\frac{3}{4}t} = e^{j\frac{3}{4}(t + T)}$$
#
# Isso ocorre quando $j\frac{3}{4}N$ é um múltiplo inteiro de $2\pi j$:
#
# $$\frac{3}{4}N = 2\pi k$$
#
# $$T = \frac{8\pi k}{3}$$
#
# $$T = \frac{8\pi }{3}$$
#
#
# c) **Periódico**
#
# $$x_3[t] = \mathrm{sen}\left(\frac{6\pi}{7}t+1 \right)$$
#
# $$x_3[t] = x_3[t + T]$$
#
# $$\mathrm{sen}\left(\frac{6\pi}{7}n+1 \right) = \mathrm{sen}\left(\frac{6\pi}{7}(t + T)+1 \right)$$
#
# Isso ocorre quando $\frac{6\pi}{7}T$ é um múltiplo inteiro de $2\pi$
#
# $$\frac{6\pi}{7}T = 2\pi k$$
#
# $$T = \frac{7}{3}k$$
#
# $$T = \frac{7}{3}$$
#
# d) **Não periódico**
#
# Para provar que o sinal $x_4[n] = \mathrm{cos}\left(\frac{n}{8}n-\pi \right)$ não é periódico, vamos considerar o caso $n = 0$.
#
# Para $n = 0$, temos:
#
# $$
# x_4[0] = \mathrm{cos}(-\pi) = -1
# $$
#
# Para $n = 8$, temos:
#
#
# $$x_4[8] = \mathrm{cos}\left(\frac{1}{8} \cdot 8 - \pi \right) = \mathrm{cos}(\frac{7}{8} \pi) = \frac{1}{2}$$
#
#
# Portanto, $x_4[0] \neq x_4[8]$, o que significa que o sinal não é periódico.
#
# e) **Não é periódico**
#
# Para $t = 0$, temos:
#
# $$
# x_5[0] = \mathrm{cos}(0) = 1
# $$
#
# Para $t = 1$, temos:
#
# $$
# x_5[1] = \mathrm{cos}\left(\frac{\pi}{8} \cdot 1^2\right) = \mathrm{cos}\left(\frac{\pi}{8}\right) = -\frac{\sqrt{2}}{2}
# $$
#
# Portanto, $x_5[0] \neq x_5[1]$, o que significa que o sinal não é periódico.
#
# f) **Periódico**
#
#  $x_6[t] = \mathrm{cos}\left(\frac{\pi}{2}t\right)\mathrm{cos}\left(\frac{\pi}{4}t\right)$ é periódico, com período fundamental $8$:
#
#
# Seja $T$ o período fundamental do sinal $x_6[t]$. Então, para todo $t$, temos:
#
#
# $$x_6[t] = x_6[t + T]$$
#
# $$
# \mathrm{cos}\left(\frac{\pi}{2}t\right)\mathrm{cos}\left(\frac{\pi}{4}t\right) = \mathrm{cos}\left(\frac{\pi}{2}(t + T)\right)\mathrm{cos}\left(\frac{\pi}{4}(t + T)\right)
# $$
#
# Usando as propriedades da trigonometria, temos:
#
# $$
# \mathrm{cos}\left(\frac{\pi}{2}t\right)\mathrm{cos}\left(\frac{\pi}{4}t\right) = \frac{1}{2} \cdot \mathrm{cos}\left(\frac{3\pi}{2}t\right) + \frac{1}{2} \cdot \mathrm{cos}\left(\frac{\pi}{2}t\right)
# $$
#
# $$
# \mathrm{cos}\left(\frac{\pi}{2}(t + T)\right)\mathrm{cos}\left(\frac{\pi}{4}(t + T)\right) = \frac{1}{2} \cdot \mathrm{cos}\left(\frac{3\pi}{2}(t + T)\right) + \frac{1}{2} \cdot \mathrm{cos}\left(\frac{\pi}{2}(t + T)\right)
# $$
#
# Para que as duas expressões sejam iguais, é necessário que:
#
# $$
# \frac{3\pi}{2}t = \frac{3\pi}{2}(t + T) \Rightarrow T = 8
# $$
#
# g)
#
# $$
# x_7[t] = x_7[t + T]
# $$
#
# Substituindo $x_7[t] = 3\cos\left(0.16\pi t + 1\right) + 4\cos\left(0.15\pi t + 2\right)$, temos:
#
# $$
# 3\cos\left(0.16\pi t + 1\right) + 4\cos\left(0.15\pi t + 2\right) = 3\cos\left(0.16\pi (t + T) + 1\right) + 4\cos\left(0.15\pi (t + T) + 2\right)
# $$
#
# Usando as propriedades da trigonometria, temos:
#
# $$
# 3\cos\left(0.16\pi t + 1\right) + 4\cos\left(0.15\pi t + 2\right) = 3\cos\left(0.16\pi t + 1\right) + 4\cos\left(0.15\pi t + 2\right)
# $$
#
# Para que as duas expressões sejam iguais, é necessário que:
#
# $$
# 0.16\pi t + 1 = 0.16\pi (t + T) + 1 \Rightarrow T = 60
# $$

# %% [markdown]
# **2)** Resolvido por Catherine Gallis
#
# a) $x_1(t) = -3$:
#
# $x_1(t) = -3 = -3e^{0t}\cos(0t + 0)$
#
# Então, $A = -3$, $a = 0$, $\omega = 0$, e $\theta = 0$
#
# b) $x_2(t) = 3e^{j\frac{\pi}{3}}\cos(2t+3\pi)$:
#
# $3e^{j\frac{\pi}{3}} = 3\cos(\frac{\pi}{3}) + j3\sin(\frac{\pi}{3}) = \frac{3}{2} + j\frac{3\sqrt{3}}{2}$
#
# $x_2(t)$ na forma $Ae^{-at}\cos(\omega t + \theta)$:
#
# $x_2(t) = \frac{3}{2}e^{-0t}\cos(2t + \frac{\pi}{3} + \pi) = \frac{3}{2}\cos(2t + \frac{4\pi}{3})$
#
# Então, $A = \frac{3}{2}$, $a = 0$, $\omega = 2$, e $\theta = \frac{4\pi}{3}$
#
# c) $x_3(t) = e^{-2t}\mathrm{sen}\left(0.5t+\frac{\pi}{2}\right)$:
#
# $x_3(t) = e^{-2t}\sin(0.5t + \frac{\pi}{2})$
#
# Então, $A = 1$, $a = 2$, $\omega = 0.5$, e $\theta = \frac{\pi}{2}$
#
# d) $x_4(t) = je^{(-3+j50)t}$:
#
# $je^{(-3+j50)t} = e^{-3t}e^{j50t}$
#
# $x_4(t) = e^{-3t}\cos(50t + \frac{\pi}{2})$
#
# Então, $A = 1$, $a = 3$, $\omega = 50$, e $\theta = \frac{\pi}{2}$

# %% [markdown]
# **3)** Resolvido por Catherine
#
# A partir do gráfico , podemos observar que o sinal \(x[n]\) é uma sequência exponencial discreta que decresce exponencialmente à medida que \(n\) aumenta. A expressão geral para esse tipo de sequência é dada por:
#
# $$x[n] = A \cdot \alpha^n$$
#
# Onde:
# - $A = 4$ é a amplitude do sinal.
# - $\alpha = -0.75$ é o fator de decréscimo exponencial.
# - $n$ é o índice de amostra.
#
# Portanto, a expressão para o sinal $x[n]$ é:
#
# $$x[n] = 4 \cdot (-0.75)^n$$

# %% [markdown]
# **4)** Resolvido por Catherine
#
#  4a) $x_1[n] = e^{-0.2n}$
#
# Sabemos que a relação entre $\lambda$ e $\alpha$ é dada por:
#
# $$\lambda = \ln(\alpha)$$
#
# Neste caso, temos \(\lambda = -0.2\) e queremos encontrar o valor de \(\alpha\):
#
# $$-0.2 = \ln(\alpha)$$
#
# $$\alpha = e^{-0.2}$$
#
# $$\alpha \approx 0.8187$$
#
# O módulo de $\alpha$ é dado por:
#
# $$|\alpha| = |e^{-0.2n}| = e^{-0.2n}$$
#
# O módulo de $x_1[n]$ é dado por:
#
# $$|x_1[n]| = |\alpha^n| = |\alpha|^n = e^{-0.2n}$$
#
# Portanto, o módulo de $x_1[n]$ é **constante**
#
# A fase de $\alpha$ e de $x_1$ é dada por:
#
# $$
# \angle \alpha = \angle e^{-0.2n} = -0.2n
# $$
#
# $$
# \angle x_1[n] = \angle (\alpha^n) = n \angle \alpha = -0.2n
# $$
#
# Portanto, a fase de $x_1[n]$ é **decrescente**.
#
# Logo, o sinal $x_1[n]$ tem módulo constante e fase decrescente.

# %%
def x1(n):
  return np.exp(-0.2 * n)

n = np.arange(-10, 10)
x = x1(n)

plt.plot(n, x)
plt.xlabel('n')
plt.ylabel('x[n]')
plt.title('Sinal x_1[n] = e^{-0.2n}')
plt.show()

# %% [markdown]
# 4b)
#
# **b)** $x_2[n] = \alpha^n$, onde $\alpha = e^{0.2n}$.
#
# Neste caso, temos \(\lambda = 0.2\) e queremos encontrar o valor de \(\alpha\):
#
# $$\lambda = \ln(\alpha)$$
#
# $$0.2 = \ln(\alpha)$$
#
# $$\alpha = e^{0.2}$$
#
# $$\alpha \approx 1.2214$$
#
# O módulo de $\alpha$ é dado por:
#
# $$
# |\alpha| = |e^{0.2n}| = e^{0.2n}
# $$
#
# O módulo de $x_2[n]$ é dado por:
#
# $$
# |x_2[n]| = |\alpha^n| = |\alpha|^n = e^{0.2n}
# $$
#
# Portanto, o módulo de $x_2[n]$ é **constante**.
#
# A fase de $\alpha$ é dada por:
#
# $$
# \angle \alpha = \angle e^{0.2n} = 0.2n
# $$
#
# A fase de $x_2[n]$ é dada por:
#
# $$
# \angle x_2[n] = \angle (\alpha^n) = n \angle \alpha = 0.2n
# $$
#
# Portanto, a fase de $x_2[n]$ é **crescente**.

# %%
def x2(n):
  return np.exp(0.2 * n)

n = np.arange(-10, 10)
x = x2(n)

plt.plot(n, x)
plt.xlabel('n')
plt.ylabel('x[n]')
plt.title('Sinal x_2[n] = e^{0.2n}')
plt.show()

# %% [markdown]
# 4c)
#
# c) $x_3[n] = e^{j\frac{\pi}{2} n}$
#
# Neste caso, temos $\lambda = j\frac{\pi}{2}$ e queremos encontrar o valor de $\alpha$:
#
# $$\lambda = \ln(\alpha)$$
#
# $$j\frac{\pi}{2} = \ln(\alpha)$$
#
# Para encontrar \(\alpha\), aplicamos a função exponencial (base \(e\)) dos dois lados:
#
# $$\alpha = e^{j\frac{\pi}{2}}$$
#
# $$\alpha = \cos(\frac{\pi}{2}) + j\sin(\frac{\pi}{2})$$
#
# $$\alpha = j$$
#
# O módulo de $\alpha$ é dado por:
#
# $$
# |\alpha| = |e^{j\frac{\pi}{2} n}| = e^{0} = 1
# $$
#
# O módulo de $x_3[n]$ é dado por:
#
# $$
# |x_3[n]| = |\alpha^n| = |\alpha|^n = 1^n = 1
# $$
#
# Portanto, o módulo de $x_3[n]$ é **constante**.
#
# A fase de $\alpha$ é dada por:
#
# $$
# \angle \alpha = \angle e^{j\frac{\pi}{2} n} = \frac{\pi}{2} n
# $$
#
# A fase de $x_3[n]$ é dada por:
#
# $$
# \angle x_3[n] = \angle (\alpha^n) = n \angle \alpha = n \frac{\pi}{2}
# $$
#
# Portanto, a fase de $x_3[n]$ é **crecente**.

# %%
def x3(n):
  return np.sin(n)

n = np.arange(-10, 10)
x = x3(n)

plt.plot(n, x)
plt.xlabel('$n$')
plt.ylabel('$x[n]$')
plt.title('$Sinal x_3[n]$')
plt.show()

# %% [markdown]
# 4d) $x_4[n] = e^{-j\frac{\pi}{2} n}$
#
# $$\lambda = \ln(\alpha)$$
#
# $$-j\frac{\pi}{2} = \ln(\alpha)$$
#
# $$\alpha = e^{-j\frac{\pi}{2}}$$
#
# $$\alpha = \cos(-\frac{\pi}{2}) + j\sin(-\frac{\pi}{2})$$
#
# $$\alpha = -j$$
#
# O módulo de $\alpha$ é dado por:
#
# $$
# |\alpha| = |e^{-j\frac{\pi}{2} n}| = e^{0} = 1
# $$
#
# O módulo de $x_4[n]$ é dado por:
#
# $$
# |x_4[n]| = |\alpha^n| = |\alpha|^n = 1^n = 1
# $$
#
# Portanto, o módulo de $x_4[n]$ é **constante**.
#
# A fase de $\alpha$ é dada por:
#
# $$
# \angle \alpha = \angle e^{-j\frac{\pi}{2} n} = -\frac{\pi}{2} n
# $$
#
# A fase de $x_4[n]$ é dada por:
#
# $$
# \angle x_4[n] = \angle (\alpha^n) = n \angle \alpha = -n \frac{\pi}{2}
# $$
#
# Portanto, a fase de $x_4[n]$ é **decrescente**.

# %%
def x4(n):
  return np.cos(n)

n = np.arange(-10, 10)
x = x4(n)

plt.plot(n, x)
plt.xlabel('n')
plt.ylabel('x[n]')
plt.title('Sinal x_4[n] = e^{-j\frac{\pi}{2} n}')
plt.show()

# %% [markdown]
# **5)** Respondido por Catherine Gallis
#
# a) $x_1(t) = \cos(3t)$
#
# Não há componente exponencial $e^{\sigma t}$ no sinal original. Portanto, $s_1$ e $s_2$ são ambos puramente imaginários:
#
# $s_1 = j \cdot 3$ e $s_2 = -j \cdot 3$
#
# b) $x_2(t) = e^{-3t} \cos(2t)$
#
# $\sigma = -3$ (parte real do termo exponencial) e $\omega_0 = 2$
#
# Portanto, $s_1 = -3 + j2$ e $s_2 = -3 - j2$
#
# c) $x_3(t) = e^{-6t}$
#
# $\sigma = -6$ (parte real do termo exponencial) e $\omega_0 = 0$ (não há parte imaginária).
#
# Portanto, $s_1 = -6$ e $s_2 = -6$
#
# d) $x_4(t) = 5$
#
# Este é um sinal constante sem componente exponencial, logo para $\sigma$ quanto $\omega_0$ o valor é 0.
#
# Portanto, $s_1 = 0$ e $s_2 = 0$
#
# e) $x_5(t) = e^{2t} \cos(4t)$
#
# $\sigma = 2$ (parte real do termo exponencial) e $\omega_0 = 4$
#
# Portanto, $s_1 = 2 + j4$ e $s_2 = 2 - j4$

# %% [markdown]
# **6)** Resolvido por Catherine Gallis
#
# a) $x_1[n] = \cos\left(\frac{2\pi}{10}n\right)$:
#
# $\frac{\pi}{5}N = 2\pi$
#
# $N = \frac{2\pi}{\frac{\pi}{5}} = 10$
#
# b) $x_2[n] = \cos\left(\frac{\pi}{10}n\right)$:
#
# $\frac{\pi}{10}N = 2\pi$
#
# $N = \frac{2\pi}{\frac{\pi}{10}} = 20$
#
# c) $x_3[n] = \cos\left(\frac{2\pi}{4}n\right) + \cos\left(\frac{2\pi}{7}n\right)$:
#
# O primeiro termo tem um período $N_1 = 4$,
#
# $\frac{2\pi}{4}N_1 = 2\pi$
#
# O segundo termo tem um período $N_2$ tal que $\frac{2\pi}{7}N_2 = 2\pi$, ou seja, $N_2 = 7$.
#
# Portanto, o período fundamental de $N = 28$.
#
# d) $x_4[n] = \frac{e^{j\frac{\pi}{4}n}+ e^{-j\frac{\pi}{4}n}}{2}$:
#
# cosseno com $w = \frac{\pi}{4}$
#
# Logo, $N = 8$, pois $\frac{2\pi}{\frac{\pi}{4}} = 8$
#
# e) $x_5[n] = \frac{e^{j\frac{\pi}{20}n}+ e^{-j\frac{\pi}{20}n}}{2}$:
#
# Cada termo exponencial complexo representa um cosseno com frequência angular \$frac{\pi}{20}$
#
# Logo, $N = 40$, pois $\frac{2\pi}{\frac{\pi}{20}} = 40$
