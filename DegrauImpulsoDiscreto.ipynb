# %% [markdown]
# # Sinais degrau e impulso unitário em tempo discreto
#
# Renato Naville Watanabe

# %% [markdown]
# ## Preparação do ambiente

# %%
# @title
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Sinal impulso unitário

# %% [markdown]
# É o sinal mais simples que existe em tempio discreto. Para representá-lo, usamos a letra $\delta$, e é definido da seguinte maneira:
#
# $$\delta[n] = \left\{\begin{array}{cc}1& ,n = 0 \\ 0& ,c.c \end{array}\right. $$
#
# O seu gráfico é o seguinte:

# %%
# @title
n = np.arange(-10,11)
x = np.zeros_like(n)
x[n==0] = 1

plt.stem(n,x)
plt.xlabel('n')
plt.xticks(n)
plt.ylabel('x');

# %% [markdown]
# Para obter um impulso unitário em outra posição que não $n=0$, basta atrasarmos (ou adiantarmos) o sinal $\delta[n]$. Se queremos que o sinal seja 1 em $n=k$, basta fazermos $\delta[n-k]$.

# %% [markdown]
# ---
#
# ### Exemplo 1
#
# Por exemplo, se queremos um impulso unitário em $n=2$, fazemos $\delta[n-2]$.

# %%
# @title
n = np.arange(-10,11)
x = np.zeros_like(n)
x[n==2] = 1

plt.stem(n,x)
plt.xlabel('n')
plt.xticks(n)
plt.ylabel('x');

# %% [markdown]
# ---

# %% [markdown]
# ## Sinal degrau
#
# Outro sinal que usaremos bastante é o sinal degrau de tempo discreto. Esse sinal é sempre igual a 1 para $n\geq 0$. Para esse sinal usaremos a letra $u$:
#
# $$u[n] =   \left\{\begin{array}{cc}1& ,n \geq 0 \\ 0& ,c.c \end{array}\right. $$
#
# O seu gráfico é mostrado abaixo:

# %%
# @title
n = np.arange(-10,11)
x = np.zeros_like(n)
x[n>=0] = 1

plt.stem(n,x)
plt.xlabel('n')
plt.xticks(n)
plt.ylabel('x');

# %% [markdown]
# Os sinais degrau e impulso unitário em tempo discreto estão bastante relacionados. O sinal impulso unitário é o sinal degrau subtraido do mesmo sinal degrau atrasado de 1 passo.
#
# $$\delta[n] = u[n] - u[n-1]$$

# %% [markdown]
# ## Exercícios
#
# **1)** Faça o gráfico dos seguintes  sinais:
#
# a) $x_1[n]=u[n] - u[n-3]$
#
# b) $x_2[n] = u[n] - 2u[n-3]+u[n-4]$
#
# c) $x_3[n] = nu[n]-2(n-1)u[n-1]+(n-3)u[n-3]$

# %% [markdown]
# **2)** Faça o gráfico dos seguintes sinais:
#
# a) $x_1[n] = u[n] - \delta[n-3]-u[n-4]$
#
# b) $x_2[n] = nu[n] - nu[n-5] + 3\delta[n-2]$
#
# c) $x_3[n] = 2\delta[n-1] - 4\delta[n-3]$

# %% [markdown]
# **3)** Considere o seguinte sinal de tempo discreto:
#
# $$x[n] = 1-\displaystyle\sum_{k=2}^{\infty}\delta[n-2-k] $$
#
# Determine os valores dos números inteiros $M$ e $n_0$ para escrever $x[n]$ na forma:
#
# $$x[n]=u[Mn-n_0] $$

# %% [markdown]
# **4)** Considere o seguinte sinal:
#
# $$x[n] = 0.5^{n-1}(u[n+2]- u[n-8])$$
#
# Encontre $a$ e $b$ na expressão abaixo:
#
# $$x[n-k] = \left\{\begin{array}{cc}0.5^{n-k-1}&\text{ , se } a< k < b \\ 0& \text{ , c.c.} \end{array}\right. $$

# %% [markdown]
# **5)** Escreva os seguintes sinais com apenas uma expressão (sem o uso de chaves com condições):
#
# a) $x_1[n] = \left\{\begin{array}{cc} n & , 0 \leq n \leq 3\\n^2&, 3< n \leq 7\\ 0& \text{c.c.} \end{array}\right.$
#
#
# b) $x_2[n] = \left\{\begin{array}{cc} \cos\left(\frac{\pi}{6}n\right) & , -3 \leq n \leq 3\\ 0&\text{c.c.} \end{array}\right.$
#
# $x[n] = \left\{\begin{array}{cc} 1 & , 0 \leq n \leq 2\\2&, 2< n \leq 7\\ 1&7 < n \leq 10 \\0&\text{c.c.} \end{array}\right.$

# %% [markdown]
# ## Referências
#
# - Oppenheim, M.  e Willsky, S., Sistemas e Sinais, 2010
# - Ulaby, FT e Yagle, AE, Signals & Systems: Theory and Applications, 2018, [ss2.eecs.umich.edu](ss2.eecs.umich.edu)

# %% [markdown]
# ## Solução dos exercícios

# %% [markdown]
# **1-)** Resolvido por Frederico Guazzelli

# %%
#1a)
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(0, 10)
x1 = np.heaviside(n, 1) - np.heaviside(n - 3, 1)

plt.stem(n, x1, use_line_collection=True)
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.title(r'$x_1[n] = u[n] - u[n-3]$')

plt.show()
# Out:
# /tmp/ipykernel_56971/1118574286.py:8: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n, x1, use_line_collection=True)

# %%
#1b)
n = np.arange(0, 10)

x2 = np.heaviside(n, 1) - 2 * np.heaviside(n - 3, 1) + np.heaviside(n - 4, 1)

plt.stem(n, x2, use_line_collection=True)
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.title(r'$x_2[n] = u[n] - 2u[n-3] + u[n-4]$')

plt.show()
# Out:
# /tmp/ipykernel_52260/2640829037.py:6: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n, x2, use_line_collection=True)

# %%
#1c)
n = np.arange(0, 10)

x3 = n * np.heaviside(n, 1) - 2 * (n - 1) * np.heaviside(n - 1, 1) + (n - 3) * np.heaviside(n - 3, 1)

plt.stem(n, x3, use_line_collection=True)
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.title(r'$x_3[n] = nu[n] - 2(n-1)u[n-1] + (n-3)u[n-3]$')

plt.show()
# Out:
# /tmp/ipykernel_52260/3793139166.py:6: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n, x3, use_line_collection=True)

# %% [markdown]
# **2-)** Resolvido por Frederico Guazzelli

# %%
#2a)
n = np.arange(0, 10)
x1 = np.heaviside(n, 1) - (n == 3) - np.heaviside(n - 4, 1)

plt.stem(n, x1, use_line_collection=True)
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.title(r'$x_1[n] = u[n] - \delta[n-3] - u[n-4]$')

plt.show()
# Out:
# /tmp/ipykernel_56971/2201575927.py:5: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n, x1, use_line_collection=True)

# %%
#2b)
n = np.arange(0, 10)
x2 = n * np.heaviside(n, 1) - n * np.heaviside(n - 5, 1) + 3 * (n == 2)


plt.stem(n, x2, use_line_collection=True)
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.title(r'$x_2[n] = nu[n] - nu[n-5] + 3\delta[n-2]$')

plt.show()
# Out:
# /tmp/ipykernel_56971/3654669483.py:6: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n, x2, use_line_collection=True)

# %%
#2c)
n = np.arange(0, 10)
x3 = 2 * (n == 1) - 4 * (n == 3)

plt.stem(n, x3, use_line_collection=True)
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.title(r'$x_3[n] = 2\delta[n-1] - 4\delta[n-3]$')

plt.show()
# Out:
# /tmp/ipykernel_56971/3998681574.py:5: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n, x3, use_line_collection=True)

# %% [markdown]
# **5)** Resolvido por Catherine
#
# a) $x_1[n] = \left\{\begin{array}{cc} n & , 0 \leq n \leq 3\\n^2&, 3< n \leq 7\\ 0& \text{c.c.} \end{array}\right.$
#
# $x_1[n] = n \cdot (u[n] - u[n - 3]) + n^2 \cdot (u[n - 3] - u[n - 7])$
#
#
#
# b) $x_2[n] = \left\{\begin{array}{cc} \cos\left(\frac{\pi}{6}n\right) & , -3 \leq n \leq 3\\ 0&\text{c.c.} \end{array}\right.$
#
# $x_2[n] = \cos\left(\frac{\pi}{6}n\right) \cdot (u[n + 3] - u[n - 3])$
#
#
#
# c) $x[n] = \left\{\begin{array}{cc} 1 & , 0 \leq n \leq 2\\2&, 2< n \leq 7\\ 1&7 < n \leq 10 \\0&\text{c.c.} \end{array}\right.$
#
# $x[n] = 1 \cdot (u[n] - u[n - 2]) + 2 \cdot (u[n - 2] - u[n - 7]) + 1 \cdot (u[n - 7] - u[n - 10])$
